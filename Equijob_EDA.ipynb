# %% [markdown]
# <a href="https://colab.research.google.com/github/shfarhaan/EquiJob/blob/main/Equijob_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importing important libraries/modules

# %%
# !pip install beautifulsoup4

# %%
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import re

# %matplotlib inline

# %% [markdown]
# # Setting the environment

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_colwidth', None)
# Set default title color
plt.style.use('fivethirtyeight')
# Set default title color
plt.rcParams.update({'text.color': "#333333", 'axes.labelcolor': "#333333"})

# set default plt figure size
plt.rcParams["figure.figsize"] = [10, 5]
# figure suptitle
plt.rcParams["figure.titlesize"] = 26
plt.rcParams["figure.titleweight"] = "bold"
# set default plt font size
# plt.rcParams["font.size"] = 24
# font weight
# plt.rcParams["font.weight"] = "bold"
# title location
plt.rcParams["axes.titlelocation"] = "left"
# title size
plt.rcParams["axes.titlesize"] = 18
# title wight
plt.rcParams["axes.titleweight"] = "bold"
plt.rcParams["axes.labelweight"] = "normal"
# spines
plt.rcParams["axes.spines.bottom"] = True
plt.rcParams["axes.spines.left"] = True
# axis labels
# plt.rcParams["xaxis.labellocation"] = "left"
# plt.rcParams["yaxis.labellocation"] = "top"
plt.rcParams["axes.labelweight"] = "bold"

plt.rcParams["font.weight"] = "bold"

# %% [markdown]
# # Load Data

# %%
data1 = pd.read_csv("/content/drive/MyDrive/EquiJob/MyDatasets/JD_Australia.csv")
data2 = pd.read_csv("/content/drive/MyDrive/EquiJob/MyDatasets/JD_Bangladesh.csv")
data3 = pd.read_csv("/content/drive/MyDrive/EquiJob/MyDatasets/JD_Denmark.csv")
data4 = pd.read_csv("/content/drive/MyDrive/EquiJob/MyDatasets/JD_Germany.csv")
data5 = pd.read_csv("/content/drive/MyDrive/EquiJob/MyDatasets/JD_Japan.csv")

data6 = pd.read_csv("/content/drive/MyDrive/EquiJob/MyDatasets/JD_Malaysia.csv")
data7 = pd.read_csv("/content/drive/MyDrive/EquiJob/MyDatasets/JD_Norway.csv")
data8 = pd.read_csv("/content/drive/MyDrive/EquiJob/MyDatasets/JD_Singapore.csv")
data9 = pd.read_csv("/content/drive/MyDrive/EquiJob/MyDatasets/JD_SouthKorea.csv")
data10 = pd.read_csv("/content/drive/MyDrive/EquiJob/MyDatasets/JD_Sweden.csv")
data11 = pd.read_csv("/content/drive/MyDrive/EquiJob/MyDatasets/JD_UnitedKingdom.csv")

# %%
# !pip install googletrans

# %%
# import csv
# from googletrans import Translator

# %%
# # Read the CSV file
# with open("/content/drive/MyDrive/EquiJob/MyDatasets/JD_SouthKorea.csv",
#           'r', newline='') as input_file:
#     reader = csv.reader(input_file)
#     data = list(reader)

# %%
# pip install langdetect

# %%
# import csv
# from googletrans import Translator
# from googletrans import LANGUAGES

# # Initialize the translator
# translator = Translator()

# # Define a function to translate a cell, handling the 'NoneType' error
# def translate_cell(cell):
#     try:
#         result = translator.translate(cell, src='ko', dest='en')
#         return result.text
#     except Exception as e:
#         print(f"Translation error for input '{cell}': {e}")
#         return cell  # Return the original text on error

# # Open the CSV file for reading and a new CSV file for writing
# with open('/content/drive/MyDrive/EquiJob/MyDatasets/JD_SouthKorea.csv', mode='r', encoding='utf-8') as csv_file, \
#         open('translated_data.csv', mode='w', newline='', encoding='utf-8') as output_file:
#     csv_reader = csv.DictReader(csv_file)
#     fieldnames = csv_reader.fieldnames

#     # Create a CSV writer for the output file
#     csv_writer = csv.DictWriter(output_file, fieldnames=fieldnames)
#     csv_writer.writeheader()

#     # Iterate through the rows and translate the data
#     for row in csv_reader:
#         translated_row = {}
#         for field in fieldnames:
#             translated_row[field] = translate_cell(row[field])
#         csv_writer.writerow(translated_row)

# print("Translation complete. Output saved to 'translated_data.csv'.")

# %%
# # Translate the data
# translator = Translator()
# translated_data = []
# for row in data:
#     translated_row = []
#     for cell in row:
#         try:
#             # Attempt to translate the cell
#             translated_cell = translator.translate(cell, dest='en').text
#         except AttributeError:
#             # If translation fails, use the original cell
#             translated_cell = cell
#         translated_row.append(translated_cell)
#     translated_data.append(translated_row)

# %%
# translated_data

# %%
data1.shape
# Out:
# (1279, 3)

# %%
dataframes = [data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11]
for data in dataframes:
    print(data.columns)
# Out:
# Index(['job_title', 'name_location', 'job_description'], dtype='object')
# Index(['job_title', 'name_location', 'job_description'], dtype='object')
# Index(['job_title', 'name_location', 'job_description'], dtype='object')
# Index(['job_title', 'name_location', 'job_description'], dtype='object')
# Index(['job_title', 'name_location', 'job_description'], dtype='object')
# Index(['job_title', 'name_location', 'job_description'], dtype='object')
# Index(['job_title', 'name_location', 'job_description'], dtype='object')
# Index(['job_title', 'name_location', 'job_description'], dtype='object')
# Index(['job_title', 'name_location', 'job_description'], dtype='object')
# Index(['job_title', 'name_location', 'job_description'], dtype='object')
# Index(['job_title', 'name_location', 'job_description'], dtype='object')

# %%
# renaming column name
column_mapping = {
    # 'Job Description': 'Job_description',
    'job_description': 'Job_description',
    # 'description': 'Job_description',
    # 'Description': 'Job_description',
    # 'Job description': 'Job_description',
    # 'Job_jd': 'Job_description',
}
dataframes = [data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11]
for df in dataframes:
    df.rename(columns=column_mapping, inplace=True)

# %%
# # renaming column name
# column_mapping = {
#     'job_description': 'Job_description',
# }
# dataframes = [df]
# for df in dataframes:
#     df.rename(columns=column_mapping, inplace=True)

# %%
data.head()
# Out:
#                                      job_title  \
# 0                           Adult Psychiatrist
# 1        Culinary Lead, Chipotle International
# 2            Chief Tornado Structural Engineer
# 3  Territory Sales Manager DACH & North Europe
# 4    Graduate/Junior Machine Learning Engineer
#
#                                        name_location  \
# 0  Interact Medical Ltd · Nottinghamshire, Englan...
# 1  Chipotle Mexican Grill · Marylebone, England, ...
# 2  BAE Systems · Samlesbury, England, United King...
# 3  Oxford Instruments plc · DACH  4 days ago  · 4...
# 4  IT Graduate · City of London, England, United ...
#
#                                      Job_description
# 0  About the job\nGeneral adult Consultant Psychi...
# 1  About the job\nCulinary Lead, Chipotle Interna...
# 2  About the job\nStructural Engineer\n\nLocation...
# 3  About the job\nWe are looking for a Territory ...
# 4  About the job\nThis job is sourced from a job ...

# %%
#concatenating data
data = pd.concat(dataframes, axis =0, ignore_index = False)

# %%
data.head()
# Out:
#                                            job_title  \
# 0                                 Data Science Cadet
# 1  Data Entry - Typist Part-Time - Work Online - ...
# 2           Work From Home Data Entry Clerk / Typing
# 3      Typist / Data Entry - Full-Time - Work Online
# 4      Typist / Data Entry - Full-Time - Work Online
#
#                                        name_location  \
# 0  Jemena · Brisbane, Queensland, Australia  4 da...
# 1  Tmkstaffingrecruiting · Australia  4 days ago ...
# 2  Tmkstaffingrecruiting · Australia  3 days ago ...
# 3  Tmkstaffingrecruiting · Australia  6 days ago ...
# 4  Tmkstaffingrecruiting · Australia  4 days ago ...
#
#                                      Job_description
# 0  About the job\nAbout Us\n\nJemena is an Austra...
# 1  About the job\nImportant : After Applying , Ch...
# 2  About the job\nWe are a leading, highly innova...
# 3  About the job\nWorking in the Data Entry field...
# 4  About the job\nWorking in the Data Entry field...

# %%
data.to_csv("All_JDs.csv")

# %%
data.shape
# Out:
# (7747, 3)

# %% [markdown]
# # Descriptive Statistics

# %%
# data12.rename(columns = {'description':'Job_description'}, inplace = True)

# %%
# data12.head()

# %%
# data = pd.merge( data11, data12, on = 'Job_description', how ='outer' )

# %%
# data.info()

# %%
print(f" No of rows : {data.shape[0]}")
print(f" No of columns: {data.shape[1]}")
# Out:
#  No of rows : 7747
#  No of columns: 3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7747 entries, 0 to 1012
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        7747 non-null   object
#  1   name_location    7661 non-null   object
#  2   Job_description  7747 non-null   object
# dtypes: object(3)
# memory usage: 242.1+ KB

# %%
data.describe(include = 'object')
# Out:
#               job_title                                      name_location  \
# count              7747                                               7661
# unique             4457                                               6046
# top     Test Specialist  GSBOA · Cheongju, North Chungcheong, South Kor...
# freq                480                                                 66
#
#                                           Job_description
# count                                                7747
# unique                                               5314
# top     About the job\nObjective of the Position\n  To...
# freq                                                  576

# %% [markdown]
# # Duplicate Handling

# %%
duplicates_per_column = data.apply(lambda x: x.duplicated().sum())
print(duplicates_per_column)
# Out:
# job_title          3290
# name_location      1700
# Job_description    2433
# dtype: int64

# %%
# Duplicates in all the columns can be ignored except the 'Job_description' column

# %%
data['Job_description'][data['Job_description'].duplicated(keep=False)].head(10)
# Out:
# 0    About the job\nAbout Us\n\nJemena is an Austra...
# 1    About the job\nImportant : After Applying , Ch...
# 2    About the job\nWe are a leading, highly innova...
# 3    About the job\nWorking in the Data Entry field...
# 4    About the job\nWorking in the Data Entry field...
# 5    About the job\nThe Data Entry Clerk/Human will...
# 6    About the job\nWorking in the Data Entry field...
# 7    About the job\nCompany Profile\n\nWith our ind...
# 8    About the job\nThe Data Entry Clerk/Human will...
# 9    About the job\nThe Data Entry Clerk/Human will...
# Name: Job_description, dtype: object

# %%
data['Job_description'].iloc[8]
# Out:
# 'About the job\nThe Data Entry Clerk/Human will be responsible for analyzing and interpreting large datasets to provide valuable insights and recommendations to the business. They will work closely with cross-functional teams to gather and analyze data, develop reports, and provide customized solutions to help the organization gain a competitive edge.\n\nResponsibilities:\n\nAnalyze large data sets using advanced statistical techniques and tools to uncover trends, opportunities, and insights.\n\nDevelop, maintain and analyze performance metrics and reports that support data-driven decision-making processes.\n\nCollaborate with stakeholders to identify business questions and translate them into data and analysis requirements.\n\nDevelop models and algorithms to help optimize business processes and drive efficiencies.\n\nDesign and execute A/B tests and experiments to identify opportunities for optimization.\n\nIdentify data quality issues and help to develop solutions to improve data 
# ...

# %%
data['Job_description'].iloc[9]
# Out:
# 'About the job\nThe Data Entry Clerk/Human will be responsible for analyzing and interpreting large datasets to provide valuable insights and recommendations to the business. They will work closely with cross-functional teams to gather and analyze data, develop reports, and provide customized solutions to help the organization gain a competitive edge.\n\nResponsibilities:\n\nAnalyze large data sets using advanced statistical techniques and tools to uncover trends, opportunities, and insights.\n\nDevelop, maintain and analyze performance metrics and reports that support data-driven decision-making processes.\n\nCollaborate with stakeholders to identify business questions and translate them into data and analysis requirements.\n\nDevelop models and algorithms to help optimize business processes and drive efficiencies.\n\nDesign and execute A/B tests and experiments to identify opportunities for optimization.\n\nIdentify data quality issues and help to develop solutions to improve data 
# ...

# %% [markdown]
# ## *-Restore point-*

# %%
df_dropped = data.drop_duplicates( subset =['Job_description'], keep ='first')

# %%
df_dropped.shape
# Out:
# (5314, 3)

# %%
# df_dropped.colmun

# %% [markdown]
# # Missing values

# %%
df_dropped.isnull().sum()
# Out:
# job_title          0
# name_location      2
# Job_description    0
# dtype: int64

# %%
df_dropped[df_dropped['Job_description'].isnull()]
# Out:
# Empty DataFrame
# Columns: [job_title, name_location, Job_description]
# Index: []

# %% [markdown]
# # *-Restore Point-*

# %%
df_final = df_dropped.dropna(subset =['Job_description'])

# %%
df_final.shape
# Out:
# (5314, 3)

# %% [markdown]
# # Drop unnecessary rows

# %%
df_final.head()
# Out:
#                                            job_title  \
# 0                                 Data Science Cadet
# 1  Data Entry - Typist Part-Time - Work Online - ...
# 2           Work From Home Data Entry Clerk / Typing
# 3      Typist / Data Entry - Full-Time - Work Online
# 5                    Data Entry/Transcription Typist
#
#                                        name_location  \
# 0  Jemena · Brisbane, Queensland, Australia  4 da...
# 1  Tmkstaffingrecruiting · Australia  4 days ago ...
# 2  Tmkstaffingrecruiting · Australia  3 days ago ...
# 3  Tmkstaffingrecruiting · Australia  6 days ago ...
# 5  Securitylockdistributors · Adelaide, South Aus...
#
#                                      Job_description
# 0  About the job\nAbout Us\n\nJemena is an Austra...
# 1  About the job\nImportant : After Applying , Ch...
# 2  About the job\nWe are a leading, highly innova...
# 3  About the job\nWorking in the Data Entry field...
# 5  About the job\nThe Data Entry Clerk/Human will...

# %% [markdown]
# # *-Restore Point-*

# %%
df = df_final.Job_description
df = df.to_frame()

# %%
df.head()
# Out:
#                                      Job_description
# 0  About the job\nAbout Us\n\nJemena is an Austra...
# 1  About the job\nImportant : After Applying , Ch...
# 2  About the job\nWe are a leading, highly innova...
# 3  About the job\nWorking in the Data Entry field...
# 5  About the job\nThe Data Entry Clerk/Human will...

# %%
def preprocess(q):

    q=str(q).lower().strip()

    q = q.replace("$","dollar")
    q = q.replace("₹","rupee")
    q = q.replace("%","percent")
    q = q.replace("@","at")
    q = q.replace("€","euro")

    q = q.replace('[math]', '')

    q = q.replace(', 000,000,000', 'b ')
    q = q.replace(', 000,000', 'm ')
    q = q.replace(', 000', 'k ')
    q = re.sub(r'([0-9]+)000000000', r'\1b', q)
    q = re.sub(r'([0-9]+)000000', r'\1m', q)
    q = re.sub(r'([0-9]+)000', r'\1k', q)


    #decontracting words
    contractions = {
    "ain't": "am not",
    "can't": "cannot",
    "can't've": "cannot have",
    "cause": "because",
    "could've": "could have",
    "couldn't": "could not",
    "couldn't've": "could not have",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hadn't've": "had not have",
    "hasn't": "has not",
    "haven't": "have not",
    "he'd": "he had / he would",
    "he'd've": "he would have",
    "he'll": "he shall / he will",
    "he'll've": "he shall have / he will have",
    "he's": "he has / he is",
    "how'd": "how did",
    "how'd'y": "how do you",
    "how'll": "how will",
    "how's": "how has / how is / how does",
    "I'd": "I had / I would",
    "I'd've": "I would have",
    "I'll": "I shall / I will",
    "I'll've": "I shall have / I will have",
    "I'm": "I am",
    "I've": "I have",
    "isn't": "is not",
    "it'd": "it had / it would",
    "it'd've": "it would have",
    "it'll": "it shall / it will",
    "it'll've": "it shall have / it will have",
    "it's": "it has / it is",
    "let's": "let us",
    "ma'am": "madam",
    "mayn't": "may not",
    "might've": "might have",
    "mightn't": "might not",
    "mightn't've": "might not have",
    "must've": "must have",
    "mustn't": "must not",
    "mustn't've": "must not have",
    "needn't": "need not",
    "needn't've": "need not have",
    "o'clock": "of the clock",
    "oughtn't": "ought not",
    "oughtn't've": "ought not have",
    "shan't": "shall not",
    "sha'n't": "shall not",
    "shan't've": "shall not have",
    "she'd": "she had / she would",
    "she'd've": "she would have",
    "she'll": "she shall / she will",
    "she'll've": "she shall have / she will have",
    "she's": "she has / she is",
    "should've": "should have",
    "shouldn't": "should not",
    "shouldn't've": "should not have",
    "so've": "so have",
    "so's": "so as / so is",
    "that'd": "that would / that had",
    "that'd've": "that would have",
    "that's": "that has / that is",
    "there'd": "there had / there would",
    "there'd've": "there would have",
    "there's": "there has / there is",
    "they'd": "they had / they would",
    "they'd've": "they would have",
    "they'll": "they shall / they will",
    "they'll've": "they shall have / they will have",
    "they're": "they are",
    "they've": "they have",
    "to've": "to have",
    "wasn't": "was not",
    "we'd": "we had / we would",
    "we'd've": "we would have",
    "we'll": "we will",
    "we'll've": "we will have",
    "we're": "we are",
    "we've": "we have",
    "weren't": "were not",
    "what'll": "what shall / what will",
    "what'll've": "what shall have / what will have",
    "what're": "what are",
    "what's": "what has / what is",
    "what've": "what have",
    "when's": "when has / when is",
    "when've": "when have",
    "where'd": "where did",
    "where's": "where has / where is",
    "where've": "where have",
    "who'll": "who shall / who will",
    "who'll've": "who shall have / who will have",
    "who's": "who has / who is",
    "who've": "who have",
    "why's": "why has / why is",
    "why've": "why have",
    "will've": "will have",
    "won't": "will not",
    "won't've": "will not have",
    "would've": "would have",
    "wouldn't": "would not",
    "wouldn't've": "would not have",
    "y'all": "you all",
    "y'all'd": "you all would",
    "y'all'd've": "you all would have",
    "y'all're": "you all are",
    "y'all've": "you all have",
    "you'd": "you had / you would",
    "you'd've": "you would have",
    "you'll": "you shall / you will",
    "you'll've": "you shall have / you will have",
    "you're": "you are",
    "you've": "you have"
    }

    q_decontracted = []

    for word in q.split():
        if word in contractions:
            word = contractions[word]
        q_decontracted.append(word)

    q = ' '.join(q_decontracted)
    q = q.replace("'ve", " have")
    q = q.replace("n't", " not")
    q = q.replace("'re", " are")
    q = q.replace("'ill", " will")

    #removing html tags
    q = BeautifulSoup(q)
    q = q.get_text()

    #removing punctuations
    pattern = re.compile('\W')

    q=re.sub(pattern , ' ', q).strip()

    return q

# %%
# preprocess
df['Job_description'] = df['Job_description'].apply(preprocess)
# remove extra spaces
df['Job_description'] = df['Job_description'].str.strip().str.replace(r'\s+', ' ', regex=True)

# %%
df.head()
# Out:
#                                      Job_description
# 0  about the job about us jemena is an australian...
# 1  about the job important after applying check i...
# 2  about the job we are a leading highly innovati...
# 3  about the job working in the data entry field ...
# 5  about the job the data entry clerk human will ...

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
stops=set(stopwords.words('english'))
import string
punctuations=list(string.punctuation)
stops.update(punctuations)
stops
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
# ...

# %%
# remove he, his, her etc from stop words as these words are important for labelling the data(gender bias column)
stops = {'!',
 '"',
 '#',
 '$',
 '%',
 '&',
 "'",
 '(',
 ')',
 '*',
 '+',
 ',',
 '-',
 '.',
 '/',
 ':',
 ';',
 '<',
 '=',
 '>',
 '?',
 '@',
 '[',
 '\\',
 ']',
 '^',
 '_',
 '`',
 'a',
 'about',
 'above',
 'after',
 'again',
 'against',
 'ain',
 'all',
 'am',
 'an',
 'and',
 'any',
 'are',
 'aren',
 "aren't",
 'as',
 'at',
 'be',
 'because',
 'been',
 'before',
 'being',
 'below',
 'between',
 'both',
 'but',
 'by',
 'can',
 'couldn',
 "couldn't",
 'd',
 'did',
 'didn',
 "didn't",
 'do',
 'does',
 'doesn',
 "doesn't",
 'doing',
 'don',
 "don't",
 'down',
 'during',
 'each',
 'few',
 'for',
 'from',
 'further',
 'had',
 'hadn',
 "hadn't",
 'has',
 'hasn',
 "hasn't",
 'have',
 'haven',
 "haven't",
 'having',
 'here',
 'how',
 'i',
 'if',
 'in',
 'into',
 'is',
 'isn',
 "isn't",
 'it',
 "it's",
 'its',
 'itself',
 'just',
 'll',
 'm',
 'ma',
 'me',
 'mightn',
 "mightn't",
 'more',
 'most',
 'mustn',
 "mustn't",
 'my',
 'myself',
 'needn',
 "needn't",
 'no',
 'nor',
 'not',
 'now',
 'o',
 'of',
 'off',
 'on',
 'once',
 'only',
 'or',
 'other',
 'our',
 'ours',
 'ourselves',
 'out',
 'over',
 'own',
 're',
 's',
 'same',
 'shan',
 "shan't",
 'she',
 "she's",
 'should',
 "should've",
 'shouldn',
 "shouldn't",
 'so',
 'some',
 'such',
 't',
 'than',
 'that',
 "that'll",
 'the',
 'their',
 'theirs',
 'them',
 'themselves',
 'then',
 'there',
 'these',
 'they',
 'this',
 'those',
 'through',
 'to',
 'too',
 'under',
 'until',
 'up',
 've',
 'very',
 'was',
 'wasn',
 "wasn't",
 'we',
 'were',
 'weren',
 "weren't",
 'what',
 'when',
 'where',
 'which',
 'while',
 'who',
 'whom',
 'why',
 'will',
 'with',
 'won',
 "won't",
 'wouldn',
 "wouldn't",
 'y',
 'you',
 "you'd",
 "you'll",
 "you're",
 "you've",
 'your',
 'yours',
 'yourself',
 'yourselves',
 '{',
 '|',
 '}',
 '~'}

# %%
def clean(q):

    words = q.split()

    # Initialize an empty list to store cleaned words
    cleaned_words = []

    # Iterate through the words and check if they are in the list of stop words
    for word in words:
        if word not in stops:
            cleaned_words.append(word)

    # Join the cleaned words into a single string with spaces
    cleaned_text = ' '.join(cleaned_words)

    return cleaned_text

# %%
clean("provides prompt courteous personalized and attentive service via telephone to all guest provides accurate information recommendation to guests on any queries regarding f b the hotel local area etc ensure that the hotel policies are implemented and are adhered to responsible for increasing departmental profitability through suggestive selling actively elicits guest s feedback and take appropriate response action responsible for maintaining high standard of hygiene and cleanliness in the work area responsible for creating accurate bills cheques for all service requests received and ensuring speedy processing thereafter job type full time salary rupee20 000 00 rupee25 000 00 per month benefits food provided health insurance leave encashment paid sick time provident fund schedule rotational shift")
# Out:
# 'provides prompt courteous personalized attentive service via telephone guest provides accurate information recommendation guests queries regarding f b hotel local area etc ensure hotel policies implemented adhered responsible increasing departmental profitability suggestive selling actively elicits guest feedback take appropriate response action responsible maintaining high standard hygiene cleanliness work area responsible creating accurate bills cheques service requests received ensuring speedy processing thereafter job type full time salary rupee20 000 00 rupee25 000 00 per month benefits food provided health insurance leave encashment paid sick time provident fund schedule rotational shift'

# %%
df['Job_description'] = df['Job_description'].apply(clean)

# %%
df.head(5)
# Out:
#                                      Job_description
# 0  job us jemena australian energy company owns o...
# 1  job important applying check inbox spam folder...
# 2  job leading highly innovative software house s...
# 3  job working data entry field great way supplem...
# 5  job data entry clerk human responsible analyzi...

# %% [markdown]
# # Label the data

# %%
masculine_words = ['Ambition', 'driven', 'lead', 'persist', 'principle', 'decision', 'superior', 'individual', 'assertive', 'strong', 'hierarchical', 'rigid', 'Silicon Valley', 'stock options', 'takes risk', 'workforce', 'autonomous', 'ping pong', 'pool table', 'must', 'competitive', 'he', ' his', 'himself','confident', 'active', 'aggressive', 'ambitious', 'fearless', 'headstrong', 'defensive', 'independent', 'dominant', 'outspoken',]
feminine_words =  ['Thoughtful', 'creative', 'adaptable', 'choose', 'curious', 'excellent', 'flexible', 'multitasking', 'health', 'imaginative', 'intuitive', 'leans in', 'plans for the future', 'resilient', 'self-aware', 'socially responsible', 'trustworthy', 'shup-to-date', 'wellness program', 'nurture', 'teach', 'dependable', 'community', 'serving', 'loyal', 'enthusiasm', 'interpersonal', 'connect', 'commit', 'she', 'agree', 'empathy','sensitive', 'affectionate', 'feel', 'support', 'collaborate', 'honest', 'trust', 'understand', 'comapssion', 'share','polite', 'kind', 'caring', 'her', 'hers', 'herself']
racial_words = ['native English speaker', 'professionally groomed hair', 'native', 'culture fit', 'non-white', 'Clean-shaven', 'neat hairstyle', 'Master', 'Slave', 'a cakewalk', 'brownbag session', 'spirit animal', 'digital native', 'servant leadership', 'tribe', 'Oriental', 'spic', 'English Fluency', 'Level Native', 'Illegals','Eskimo', 'Latino', 'Latina', 'Migrant', 'blacklist', 'whitelist']

# %%
from collections import Counter
word_counts = Counter(racial_words)
value = [word for word, count in word_counts.items() if count > 1]

# %%
value
# Out:
# []

# %%
print("No of masculine words identified : ", len(masculine_words))
print("No of feminine words identified : ", len(feminine_words))
print("No of racial words identified : ", len(racial_words))
# Out:
# No of masculine words identified :  34
# No of feminine words identified :  48
# No of racial words identified :  26

# %%
masculine = [item.lower() for item in masculine_words]
feminine = [item.lower() for item in feminine_words]
racial = [item.lower() for item in racial_words]
masculine.sort()
feminine.sort()
racial.sort()

# %%
racial
# Out:
# ['a cakewalk',
#  'blacklist',
#  'brownbag session',
#  'clean-shaven',
#  'culture fit',
#  'digital native',
#  'english fluency',
#  'eskimo',
#  'illegals',
#  'latina',
#  'latino',
#  'level native',
#  'master',
#  'migrant',
#  'native',
#  'native english speaker',
#  'neat hairstyle',
#  'non-white',
#  'oriental',
#  'professionally groomed hair',
#  'servant leadership',
#  'slave',
#  'spic',
#  'spirit animal',
#  'tribe',
#  'whitelist']

# %%
from nltk.tokenize import wordpunct_tokenize
def tokenize_text(text):
    return wordpunct_tokenize(text)

# Apply the tokenize_text function to create a new 'Tokenized_Description' column
df['Tokenized_Description'] = df['Job_description'].apply(tokenize_text)

# %%
df.head()
# Out:
#                                      Job_description  \
# 0  job us jemena australian energy company owns o...
# 1  job important applying check inbox spam folder...
# 2  job leading highly innovative software house s...
# 3  job working data entry field great way supplem...
# 5  job data entry clerk human responsible analyzi...
#
#                                Tokenized_Description
# 0  [job, us, jemena, australian, energy, company,...
# 1  [job, important, applying, check, inbox, spam,...
# 2  [job, leading, highly, innovative, software, h...
# 3  [job, working, data, entry, field, great, way,...
# 5  [job, data, entry, clerk, human, responsible, ...

# %%
import nltk
from nltk import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
def lemmatize_text(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text])

# Apply the lemmatize_text function to create a new 'Lemmatized_Description' column
df['Lemmatized_Description'] = df['Tokenized_Description'].apply(lemmatize_text)
df['Lemmatized_Description_real'] = df['Lemmatized_Description'].apply(tokenize_text)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
df.head()
# Out:
#                                      Job_description  \
# 0  job us jemena australian energy company owns o...
# 1  job important applying check inbox spam folder...
# 2  job leading highly innovative software house s...
# 3  job working data entry field great way supplem...
# 5  job data entry clerk human responsible analyzi...
#
#                                Tokenized_Description  \
# 0  [job, us, jemena, australian, energy, company,...
# 1  [job, important, applying, check, inbox, spam,...
# 2  [job, leading, highly, innovative, software, h...
# 3  [job, working, data, entry, field, great, way,...
# 5  [job, data, entry, clerk, human, responsible, ...
#
#                               Lemmatized_Description  \
# 0  job u jemena australian energy company owns op...
# 1  job important applying check inbox spam folder...
# 2  job leading highly innovative software house s...
# 3  job working data entry field great way supplem...
# ...

# %%
def digits_strip(text):
    return re.sub(r'\d', '', text)

# Apply the digits_strip function to create a new column 'tokenized_digits_stripped'
df['tokenized_digits_stripped'] = df['Lemmatized_Description'].apply(digits_strip)
df['tokenized_digits_stripped_real'] = df['tokenized_digits_stripped'].apply(tokenize_text)

# %%
df['Length_before'] = [len(df['Lemmatized_Description_real'][i]) for i in df.index]
df['Length_after'] = [len(df['tokenized_digits_stripped_real'][i]) for i in df.index]

# %%
df1 = df[['Job_description', 'Length_after', 'tokenized_digits_stripped_real']]

# %%
df1.rename(columns={'Length_after' : 'Length', 'tokenized_digits_stripped_real': 'Lemmatized_description'}, inplace = True)
# Out:
# <ipython-input-57-8ef4527bab0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns={'Length_after' : 'Length', 'tokenized_digits_stripped_real': 'Lemmatized_description'}, inplace = True)

# %%
df1.head()
# Out:
#                                      Job_description  Length  \
# 0  job us jemena australian energy company owns o...      11
# 1  job important applying check inbox spam folder...      10
# 2  job leading highly innovative software house s...      10
# 3  job working data entry field great way supplem...      10
# 5  job data entry clerk human responsible analyzi...      10
#
#                               Lemmatized_description
# 0  [job, u, jemena, australian, energy, company, ...
# 1  [job, important, applying, check, inbox, spam,...
# 2  [job, leading, highly, innovative, software, h...
# 3  [job, working, data, entry, field, great, way,...
# 5  [job, data, entry, clerk, human, responsible, ...

# %%
def bias(text):
    male_count = 0
    female_count = 0
    racial_count = 0


    for word in text.split():
        if word in masculine:
            male_count += 1
        if word in feminine:
            female_count += 1
        if word in racial:
            racial_count +=1

    return pd.Series({'male_bias': male_count, 'female_bias': female_count, 'racial_bias' : racial_count})

# Apply the bias function to each row and update 'male_bias' and 'female_bias' columns
df1[['male_bias', 'female_bias', 'racial_bias']] = df['Lemmatized_Description'].apply(bias)
# Out:
# <ipython-input-59-a52b96a0380a>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['male_bias', 'female_bias', 'racial_bias']] = df['Lemmatized_Description'].apply(bias)
# <ipython-input-59-a52b96a0380a>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[['male_bias', 'female_bias', 'racial_bias']] = df['Lemmatized_Description'].apply(bias)
# <ipython-input-59-a52b96a0380a>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.head()
# Out:
#                                      Job_description  \
# 0  job us jemena australian energy company owns o...
# 1  job important applying check inbox spam folder...
# 2  job leading highly innovative software house s...
# 3  job working data entry field great way supplem...
# 5  job data entry clerk human responsible analyzi...
#
#                                Tokenized_Description  \
# 0  [job, us, jemena, australian, energy, company,...
# 1  [job, important, applying, check, inbox, spam,...
# 2  [job, leading, highly, innovative, software, h...
# 3  [job, working, data, entry, field, great, way,...
# 5  [job, data, entry, clerk, human, responsible, ...
#
#                               Lemmatized_Description  \
# 0  job u jemena australian energy company owns op...
# 1  job important applying check inbox spam folder...
# 2  job leading highly innovative software house s...
# 3  job working data entry field great way supplem...
# ...

# %%
df1['% male_bias'] = (df1['male_bias']/df1['Length'])*100
df1['% female_bias'] = (df1['female_bias']/df1['Length'])*100
df1['% racial_bias'] = (df1['racial_bias']/df1['Length'])*100
# Out:
# <ipython-input-61-abe44d9534ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['% male_bias'] = (df1['male_bias']/df1['Length'])*100

# %%
df1.head()
# Out:
#                                      Job_description  Length  \
# 0  job us jemena australian energy company owns o...      11
# 1  job important applying check inbox spam folder...      10
# 2  job leading highly innovative software house s...      10
# 3  job working data entry field great way supplem...      10
# 5  job data entry clerk human responsible analyzi...      10
#
#                               Lemmatized_description  male_bias  female_bias  \
# 0  [job, u, jemena, australian, energy, company, ...          2            7
# 1  [job, important, applying, check, inbox, spam,...          1            0
# 2  [job, leading, highly, innovative, software, h...          2            2
# 3  [job, working, data, entry, field, great, way,...          1            0
# 5  [job, data, entry, clerk, human, responsible, ...          5            3
#
#    racial_bias  % male_bias  % female_bias  % racial_bias
# 0            0    18.181818      63.636364            0.0
# ...

# %%
df1.describe()
# Out:
#             Length    male_bias  female_bias  racial_bias  % male_bias  \
# count  5314.000000  5314.000000  5314.000000  5314.000000  5314.000000
# mean     16.733346     2.063041     3.516748     0.179902    38.747479
# std      59.480873     2.521501     4.465587     0.682939    57.111418
# min       2.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     0.000000     0.000000     0.000000     0.000000
# 50%       6.000000     1.000000     2.000000     0.000000    20.000000
# 75%       7.000000     3.000000     5.000000     0.000000    57.142857
# max    1027.000000    27.000000    52.000000    18.000000   900.000000
#
#        % female_bias  % racial_bias
# count    5314.000000    5314.000000
# mean       67.381946       3.500339
# std       107.016129      15.056841
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%        33.333333       0.000000
# 75%        83.333333       0.000000
# ...

# %%
df1['male_bias_yes'] = np.where(df1['male_bias'] > 0, 1, 0)
df1['female_bias_yes'] = np.where(df1['female_bias'] > 0, 1, 0)
df1['racial_bias_yes'] = np.where(df1['racial_bias'] > 0, 1, 0)

# %%
df1.head()
# Out:
#                                      Job_description  Length  \
# 0  job us jemena australian energy company owns o...      11
# 1  job important applying check inbox spam folder...      10
# 2  job leading highly innovative software house s...      10
# 3  job working data entry field great way supplem...      10
# 5  job data entry clerk human responsible analyzi...      10
#
#                               Lemmatized_description  male_bias  female_bias  \
# 0  [job, u, jemena, australian, energy, company, ...          2            7
# 1  [job, important, applying, check, inbox, spam,...          1            0
# 2  [job, leading, highly, innovative, software, h...          2            2
# 3  [job, working, data, entry, field, great, way,...          1            0
# 5  [job, data, entry, clerk, human, responsible, ...          5            3
#
#    racial_bias  % male_bias  % female_bias  % racial_bias  male_bias_yes  \
# ...

# %%
df1.head()

# %%
male_bias_Jds = (df1['male_bias_yes'].value_counts()[1])/len(df1['male_bias_yes']) *100

# %%
female_bias_Jds = (df1['female_bias_yes'].value_counts()[1])/len(df1['female_bias_yes']) * 100

# %%
racial_bias_Jds = (df1['racial_bias_yes'].value_counts()[1])/len(df1['racial_bias_yes']) * 100

# %%
print(f'Percentage of JDs with male bias : {male_bias_Jds}')
# Out:
# Percentage of JDs with male bias : 65.05457282649604

# %%
print(f'Percentage of JDs with female bias : {female_bias_Jds}')
# Out:
# Percentage of JDs with female bias : 74.89649981181785

# %%
both_bias = (len(df1[(df1['male_bias_yes'] == 1) & (df1['female_bias_yes'] == 1)]))/len(df1) *100

# %%
print(f'Percentage of JDs with both male and female bias : {both_bias}')
# Out:
# Percentage of JDs with both male and female bias : 57.69665035754611

# %%
print(f'Percentage of JDs with racial bias : {racial_bias_Jds}')
# Out:
# Percentage of JDs with racial bias : 12.53293187805796

# %%
df1.describe()
# Out:
#             Length    male_bias  female_bias  racial_bias  % male_bias  \
# count  5314.000000  5314.000000  5314.000000  5314.000000  5314.000000
# mean     16.733346     2.063041     3.516748     0.179902    38.747479
# std      59.480873     2.521501     4.465587     0.682939    57.111418
# min       2.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     0.000000     0.000000     0.000000     0.000000
# 50%       6.000000     1.000000     2.000000     0.000000    20.000000
# 75%       7.000000     3.000000     5.000000     0.000000    57.142857
# max    1027.000000    27.000000    52.000000    18.000000   900.000000
#
#        % female_bias  % racial_bias  male_bias_yes  female_bias_yes  \
# count    5314.000000    5314.000000    5314.000000      5314.000000
# mean       67.381946       3.500339       0.650546         0.748965
# std       107.016129      15.056841       0.476843         0.433649
# ...

# %%
df1.head()
# Out:
#                                      Job_description  Length  \
# 0  job us jemena australian energy company owns o...      11
# 1  job important applying check inbox spam folder...      10
# 2  job leading highly innovative software house s...      10
# 3  job working data entry field great way supplem...      10
# 5  job data entry clerk human responsible analyzi...      10
#
#                               Lemmatized_description  male_bias  female_bias  \
# 0  [job, u, jemena, australian, energy, company, ...          2            7
# 1  [job, important, applying, check, inbox, spam,...          1            0
# 2  [job, leading, highly, innovative, software, h...          2            2
# 3  [job, working, data, entry, field, great, way,...          1            0
# 5  [job, data, entry, clerk, human, responsible, ...          5            3
#
#    racial_bias  % male_bias  % female_bias  % racial_bias  male_bias_yes  \
# ...

# %%
df1.to_csv("final_dataset(Farhaan).csv")
